# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Dataset.csv')

# %%
df.head()
# Out:
#    cgpa  package(in LPA)
# 0  6.89             3.26
# 1  5.12             1.98
# 2  7.82             3.25
# 3  7.42             3.67
# 4  6.94             3.57

# %%
import pandas as pd

import matplotlib.pyplot as plt 
# Ensure the dataframe is loaded before plotting
if 'df' not in globals():
    df = pd.read_csv('Dataset.csv')

plt.scatter(df['cgpa'], df['package(in LPA)'])
plt.xlabel('cgpa')
plt.ylabel('package(in LPA)')
# Out:
# Text(0, 0.5, 'package(in LPA)')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package(in LPA), Length: 200, dtype: float64

# %%
# %pip install -U scikit-learn

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=2
)
x_train,x_test,y_train,y_test=train_test_split (x,y,test_size=0.2, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 x_train,x_test,y_train,y_test=train_test_split (x,y,test_size=0.2, random_state=2)
#
# ModuleNotFoundError: No module named 'sklearn'
